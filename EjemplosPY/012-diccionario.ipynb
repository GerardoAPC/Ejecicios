# %%
def run():
    mi_diccionario ={
        'llave1':1,
        'llave2':2,
        'llave3':3,
    }
    print (mi_diccionario)
    print (mi_diccionario['llave1'])
    print (mi_diccionario['llave2'])
    print (mi_diccionario['llave3'])

    poblacion_paises = {
        'Argentina': 23998488,
        'Brasil': 29847555,
        'Colombia': 5389337
    }
    print (poblacion_paises['Colombia'])

    for pais in poblacion_paises.keys():
        print(pais)
    for pais in poblacion_paises.values():
        print(pais)
    for pais,poblacion in poblacion_paises.items():
         print(pais + " tiene  " + str(poblacion) + " habitantes")

    # agregar un item
    poblacion_paises.update({"USA": 1000000000})
    # eliminar un registrso
 
    del poblacion_paises["Argentina"]
    poblacion_paises.pop("Colombia")

    # cambiar valor 
    poblacion_paises["Brasil"] = 1000

    print (poblacion_paises)

# %%
# Punto de arranque 
run()
# Out:
# {'llave1': 1, 'llave2': 2, 'llave3': 3}
# 1
# 2
# 3
# 5389337
# Argentina
# Brasil
# Colombia
# 23998488
# 29847555
# 5389337
# Argentina tiene  23998488 habitantes
# Brasil tiene  29847555 habitantes
# Colombia tiene  5389337 habitantes
# {'Brasil': 1000, 'USA': 1000000000}

# %%
my_dict = {"1": "Facundo", "lastname": "García"}

# %%
# Defino la varible 'futbolistas' como un diccionario. No es necesario declarar que tipo de dato es
futbolistas = dict()

futbolistas = {
    1  : "Casillas", 
    15 : "Ramos",
    3 : "Pique", 
    5 : "Puyol",
    11 : "Capdevila", 
    14 : "Xabi Alonso",
    16 : "Busquets", 
    8 : "Xavi Hernandez",
    18 : "Pedrito", 
    6 : "Iniesta",
    7 : "Villa"
}

# %%
# Recorrer un diccionario, imprimiendo su clave-valor
for k,v in futbolistas.items():
    print(" codigo  " + str(k) + " nombre  " + str(v) )
# Out:
#  codigo  1 nombre  Casillas
#  codigo  15 nombre  Ramos
#  codigo  3 nombre  Pique
#  codigo  5 nombre  Puyol
#  codigo  11 nombre  Capdevila
#  codigo  14 nombre  Xabi Alonso
#  codigo  16 nombre  Busquets
#  codigo  8 nombre  Xavi Hernandez
#  codigo  18 nombre  Pedrito
#  codigo  6 nombre  Iniesta
#  codigo  7 nombre  Villa

# %%
# Declaración de un diccionario
diccionario = dict()

# Devuelve el numero de elementos que tiene el diccionario
len(dict)

# Compara el número de elementos distintos que tienen los dos 
cmp (dict1,dict2)

# Devuelve una lista con las claves del diccionario
dict.keys()

# Devuelve una lista con los valores del diccionario
dict.values()

# Devuelve el valor del elemento con clave key. Sino devuelve default
dict.get(key, default=None)

# Inserta un elemento en el diccionario clave:valor. Si la clave existe no lo inserta
dict.setdefault(key, default=None)

# Insertamos un elemento en el diccionario con su clave:valor
dict['key'] = 'value'

# Eliminamos el elemento del diccionario con clave key
dict.pop('key',None)

# Devuleve la copia de un diccionario dict2 = dict.copy()
dict.copy()

# Elimina todos los elementos de un diccionario
dict.clear()

# Crea un nuevo diccionario poniendo como claves las que hay en la lista y los valores por defecto si se les pasa
dict.fromkeys(list, defaultValue)

# Devuelve true si existe la clave. Sino devuelve false
dict.has_key(key)

# devuelve un lista de tuplas formadas por los pares clave:valor
dict.items()

# Añade los elementos de un diccionario a otro
dict.update(dict2)

# %%
futbolistas['9'] = 'luis'

# %%
print (futbolistas)
# Out:
# {1: 'Casillas', 15: 'Ramos', 3: 'Pique', 5: 'Puyol', 11: 'Capdevila', 14: 'Xabi Alonso', 16: 'Busquets', 8: 'Xavi Hernandez', 18: 'Pedrito', 6: 'Iniesta', 7: 'Villa', '9': 'luis'}

# %%
super_list = [
        {"firstname": "Facundo", "lastname": "García"},
        {"firstname": "Miguel", "lastname": "Rodriguez"},
        {"firstname": "Pablo", "lastname": "Trinidad"},
        {"firstname": "Susana", "lastname": "Martinez"},
        {"firstname": "José", "lastname": "Fernandez"},
    ]

# %%
print (super_list)
# Out:
# [{'firstname': 'Facundo', 'lastname': 'García'}, {'firstname': 'Miguel', 'lastname': 'Rodriguez'}, {'firstname': 'Pablo', 'lastname': 'Trinidad'}, {'firstname': 'Susana', 'lastname': 'Martinez'}, {'firstname': 'José', 'lastname': 'Fernandez'}]

# %%
super_list.append({"firstname": "Ruben", "lastname": "Rengifo"})

# %%
print (super_list)
# Out:
# [{'firstname': 'Facundo', 'lastname': 'García'}, {'firstname': 'Miguel', 'lastname': 'Rodriguez'}, {'firstname': 'Pablo', 'lastname': 'Trinidad'}, {'firstname': 'Susana', 'lastname': 'Martinez'}, {'firstname': 'José', 'lastname': 'Fernandez'}, {'firstname': 'Ruben', 'lastname': 'Rengifo'}]

# %%
for i in range(len(super_list)):
    print(super_list[i])
# Out:
# {'firstname': 'Facundo', 'lastname': 'García'}
# {'firstname': 'Miguel', 'lastname': 'Rodriguez'}
# {'firstname': 'Pablo', 'lastname': 'Trinidad'}
# {'firstname': 'Susana', 'lastname': 'Martinez'}
# {'firstname': 'José', 'lastname': 'Fernandez'}
# {'firstname': 'Ruben', 'lastname': 'Rengifo'}

# %%
del super_list[2]

# %%
for i in range(len(super_list)):
    print(super_list[i])
# Out:
# {'firstname': 'Facundo', 'lastname': 'García'}
# {'firstname': 'Miguel', 'lastname': 'Rodriguez'}
# {'firstname': 'Susana', 'lastname': 'Martinez'}
# {'firstname': 'José', 'lastname': 'Fernandez'}
# {'firstname': 'Ruben', 'lastname': 'Rengifo'}

# %%
super_list.remove({'firstname': 'Facundo', 'lastname': 'García'})

# %%
for i in range(len(super_list)):
    print(super_list[i])
# Out:
# {'firstname': 'Miguel', 'lastname': 'Rodriguez'}
# {'firstname': 'Susana', 'lastname': 'Martinez'}
# {'firstname': 'José', 'lastname': 'Fernandez'}
# {'firstname': 'Ruben', 'lastname': 'Rengifo'}
