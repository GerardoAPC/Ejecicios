# %% [markdown]
# ## 001 ejemplo 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pesos = input ("¿ cuántos pesos colombianos tienes ?:")
# Out:
# ¿ cuántos pesos colombianos tienes ?:100

# %%
pesos = float ( pesos)
valor_dolar = 3875
dolares = pesos / valor_dolar
dolares = round (dolares, 2)
dolares = str (dolares)
print ("Tienes $" + dolares + " dolares ")
# Out:
# Tienes $0.01 dolares

# %% [markdown]
# ### 002 ejemplo 2

# %%
currency = input("Type your country ")
amount = input("Type amount of money ")
# Out:
# Type your country Chile
# Type amount of money 500

# %%
amount = int(amount)
if currency == "Argentina":
    dollar_value = 70.22
    dollar_eq = amount / dollar_value
    dollar_eq = float(dollar_eq)
    dollar_eq = round(dollar_eq, 2)
    dollar_eq = str(dollar_eq)
    print("You have U$S " + dollar_eq)
elif currency == 'Chile':
    dollar_value = 786.50
    dollar_eq = amount / dollar_value
    dollar_eq = float(dollar_eq)
    dollar_eq = round(dollar_eq, 2)
    dollar_eq = str(dollar_eq)
    print("You have U$S " + dollar_eq)
else:
    print("Fatal error #1")
# Out:
# You have U$S 0.64
