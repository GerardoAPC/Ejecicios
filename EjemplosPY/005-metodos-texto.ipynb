# %% [markdown]
# ### metodo para cadenas de texto

# %%
def metodos_string():
    print("")
    print("""
    Bienvenido, este es un resumen de aplicación para métodos de strings en python, 
    por favor escribe tu nombres y apellidos según te indique la consola:
    """)
    nombre = input("Escribe tu(s) nombre(s): ")
    apellido = input("Escribe tu(s) apellido(s): ")
    print("")
    nombre = nombre + " " + apellido
    print("El nombre que ingresaste es " + nombre)
    print("""
    A continuación aplicaremos todos los métodos de strings para tu nombre:
    """)
    print("Aplicando el método  UPPER  tenemos como resultado...nombre.upper() >>> " + nombre.upper())
    nombre = nombre.upper()
    print("Aplicando el método  LOWER  tenemos como resultado...nombre.lower() >>> " + nombre.lower())
    nombre = nombre.lower()
    print("Aplicando el método  CAPITALIZE  tenemos como resultado...nombre.capitalize() >>> " + nombre.capitalize())
    nombre = nombre.capitalize()
    print("Aplicando el método  TITLE  tenemos como resultado...nombre.title() >>> " + nombre.title())
    nombre = nombre.title()
    print("Aplicando el método  STRIP  tenemos como resultado...nombre.strip("a") >>> " + nombre.strip("a"))
    nombre = nombre.strip("a")
    print("Aplicando el método  REPLACE  tenemos como resultado...nombre.replace('a','o') >>> " + nombre.replace("a", "o"))
    nombre = nombre.replace("a","o")
    print("")
    print("El resultado final de tu nombre es " + nombre + ", por cierto la longitud de caracteres que tiene tu nombre es de ---> " + str(len(nombre)) + " <--- caracteres")
    print("")

# %%
metodos_string()
# Out:
#     Bienvenido, este es un resumen de aplicación para métodos de strings en python,
#     por favor escribe tu nombres y apellidos según te indique la consola:
#
# Escribe tu(s) nombre(s): gerardo antonio
# Escribe tu(s) apellido(s): perez clavijo
#
# El nombre que ingresaste es gerardo antonio perez clavijo
#
#     A continuación aplicaremos todos los métodos de strings para tu nombre:
#
# Aplicando el método  UPPER  tenemos como resultado...nombre.upper() >>> GERARDO ANTONIO PEREZ CLAVIJO
# Aplicando el método  LOWER  tenemos como resultado...nombre.lower() >>> gerardo antonio perez clavijo
# Aplicando el método  CAPITALIZE  tenemos como resultado...nombre.capitalize() >>> Gerardo antonio perez clavijo
# Aplicando el método  TITLE  tenemos como resultado...nombre.title() >>> Gerardo Antonio Perez Clavijo
# Aplicando el método  STRIP  tenemos como resultado...nombre.strip() >>> Gerardo Antonio Perez Clavijo
# Aplicando el método  REPLACE  tenemos como resultado...nombre.replace('a','o') >>> Gerordo Antonio Perez Clovijo
#
# El resultado final de tu nombre es Gerordo Antonio Perez Clovijo, por cierto la longitud de caracteres que tiene tu nombre es de ---> 29 <--- caracteres

# %%
ge
