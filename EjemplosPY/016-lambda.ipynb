# %% [markdown]
# Una función lambda es una función anónima, y se utilizan en Python a la hora de programar para abreviar, ya que aligera la sintaxis del código. Además, no ocupan lugar en el espacio de nombres asociado a las funciones de una aplicación.

# %% [markdown]
# Por ejemplo, para calcular el área de un triángulo, podemos construir la función:

# %%
def area_triangulo(b, h):
    return b * h / 2

# %%
for b in range(1, 10, 5):
    for h in range(1, 10, 5):
        print(
            f"El área del triángulo de base {b} y altura {h} es {area_triangulo(b, h)}."
        )
# Out:
# El área del triángulo de base 1 y altura 1 es 0.5.
# El área del triángulo de base 1 y altura 6 es 3.0.
# El área del triángulo de base 6 y altura 1 es 3.0.
# El área del triángulo de base 6 y altura 6 es 18.0.

# %% [markdown]
# No obstante, una función tan sencilla puede ser abreviada como una función lambda.

# %%
area_triangulo = lambda b, h: b * h / 2

for b in range(1, 10, 5):
    for h in range(1, 10, 5):
        print(
            f"El área del triángulo de base {b} y altura {h} es {area_triangulo(b, h)}."
        )
# Out:
# El área del triángulo de base 1 y altura 1 es 0.5.
# El área del triángulo de base 1 y altura 6 es 3.0.
# El área del triángulo de base 6 y altura 1 es 3.0.
# El área del triángulo de base 6 y altura 6 es 18.0.

# %% [markdown]
# Tengo la siguiente función en Python:

# %%
def carta(lista):
    a = ''
    for i in lista:
        if(i[:2] == 'CC') & ((i[-3:] != 'CC/')):
            a = i
    return a

# %%
carta(['CC845', 'RF456', 'BG838'])
# Out:
# 'CC845'

# %%
carta_lambda = lambda lista : ('CC' in lista [:2]) + lista and ('CC/' not in lista [-3:]) + lista

# %%
x = lambda a, b: (b, a)
print(x(3, 9))
# Salida (9,3)
# Out:
# (9, 3)
