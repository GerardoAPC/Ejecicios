# %% [markdown]
# # Modelo definitivo Educación Continua
#
# ## Tabla de contenidos
#     1. Carga librerías y base de datos
#     2. Manejo de bases de datos
#     3. Construcción modelo definitivo
#     4. Plan piloto
#
# ## Carga librerías y base de datos

# %%
# %pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytrends
#   Downloading pytrends-4.8.0.tar.gz (19 kB)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.8/dist-packages (from pytrends) (2.23.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from pytrends) (1.3.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from pytrends) (4.9.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->pytrends) (2022.6)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->pytrends) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.0->pytrends) (3.0.4)
# Building wheels for collected packages: pytrends
#   Building wheel for pytrends (setup.py) ... done
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16127 sha256=346f05fe5ea772f8bb010b9b5c784ef0e5f8df6936a8896bffd615bc811d5dcd
#   Stored in directory: /root/.cache/pip/wheels/e8/78/c8/18d4f4804753e14416809b365773220c48b41fe5387f2bb6b9
# Successfully built pytrends
# Installing collected packages: pytrends
# Successfully installed pytrends-4.8.0

# %%
# %pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.0 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.6

# %%
import os
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms
import datetime as dt
import unidecode
from pytrends.request import TrendReq
import math
from datetime import datetime
# from flask import request
import time
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.pipeline import Pipeline
# import statsmodels.api as sm

plt.style.use('ggplot')

# /mnt/analiticastorage_educacion-continua
# Cambiar directorio de trabajo #
# os.chdir('/Users/JUANGARCESC/Documents/OneDrive - Universidad de Los Andes/2021/008-21 Modelo EDCO/Bases')

# Cargar base de datos con direcciones #
base=pd.read_csv('/content/ConsultaGT.csv')

base=base.drop_duplicates(['Consecutivo.del.curso']).reset_index()

# Transformaciones a variables de la base
base['Valor.por.hora']=pd.to_numeric(base['Valor.por.hora'].str.replace('[^\w\s]', ''))
base['Curso.nuevo'] = base['Curso.nuevo'].replace({'Sí':1, 'No':0})

# Dimensiones de la base de datos
base.shape
# Out:
# <ipython-input-3-c213cfa9c126>:39: FutureWarning: The default value of regex will change from True to False in a future version.
#   base['Valor.por.hora']=pd.to_numeric(base['Valor.por.hora'].str.replace('[^\w\s]', ''))
# (1310, 82)

# %% [markdown]
# ## Manejo de bases de datos

# %%
# Variables continuas:
feature_cols = ['maDesemp', 'maIPC', 'maTasaInt', 'maTRM', 'maGT_EduCon', 'maGT_Coursera', 'maGT_Cursos', 
                'maGT_Cert', 'maGT_platzi', 'maGT_udemy', 'trafico', 'clics', 'CTR', 'CPC', 'campanias', 
                'Envios', 'Aperturas', 'Clics', 'TasaApertura', 'TasaClicEn', 'TasaClicAp', 'NumCursos',
                'NumCursosFac', 'Keywords', 'Valor.por.hora']

# Variables categóricas:
feature_cat=['Exitoso2', 'Facultad', 'Modalidad', 'Categoría', 'Curso.nuevo', 'Programa']

# Establecer la base con variables a incluir
X = base[feature_cols+feature_cat]

# Eliminar valores vacíos en variables de marketing 
X=X[X['trafico'].notna()]

## Imputar info a variables con NA
# Variables a reemplazar con 0
var0=['CTR','CPC','campanias', 'Envios', 'Aperturas', 'Clics', 'TasaApertura','Keywords']
X[var0] = X[var0].replace({np.nan:0})

# Variables a imputar con media
varM=['Valor.por.hora']
X[varM]=X[varM].fillna(X[varM].mean())

# Dummies de variables categoricas
Categoria_dummies = pd.get_dummies(X.Categoría, prefix='Cat')
Categoria_dummies.drop(Categoria_dummies.columns[0], axis=1, inplace=True)

Modalidad_dummies = pd.get_dummies(X.Modalidad, prefix='Mod')
Modalidad_dummies.drop(Modalidad_dummies.columns[0], axis=1, inplace=True)

Facultad_dummies = pd.get_dummies(X.Facultad, prefix='Fac')
Facultad_dummies.drop(Facultad_dummies.columns[0], axis=1, inplace=True)


#X = pd.concat([X.drop(columns=['Facultad', 'Modalidad', 'Categoría']), Categoria_dummies, Modalidad_dummies, Facultad_dummies], axis=1)

# %%
#X = X.withColumn('Keywords', F.regexp_replace(F.col('Keywords'), ',', '.').cast('float'))

# %%
X[['Curso.nuevo',	'Programa',	'NumCursos',	'NumCursosFac',	'Keywords',	'Valor.por.hora',	'Categoría',	'Modalidad',	'Facultad'	,'Exitoso2',	'Keywords']]
# Out:
#       Curso.nuevo  Programa  NumCursos  NumCursosFac   Keywords  \
# 0               0         1          6             1   6.238095
# 1               1         1          6             4   6.977778
# 2               1         1          6             4   7.571429
# 3               1         1          6             1  12.566667
# 4               0         1          6             4   6.977778
# ...           ...       ...        ...           ...        ...
# 1303            0         0         43             9  26.714286
# 1304            0         0         43             4  50.285714
# 1305            0         0         43             9  18.375000
# 1306            0         0         43             9  19.071429
# 1307            1         0         43             6   8.380952
#
#       Valor.por.hora                        Categoría   Modalidad  \
# 0       45000.000000        Actualización Profesional  Presencial
# 1           0.000000  Bienestar - Desarrollo Personal  Presencial
# 2           0.000000  Bienestar - Desarrollo Personal  Presencial
# 3       64951.430837                  Niños y Jóvenes  Presencial
# 4       37500.000000  Bienestar - Desarrollo Personal  Presencial
# ...              ...                              ...         ...
# 1303    61500.000000        Actualización Profesional     Virtual
# 1304    71281.000000        Actualización Profesional     Virtual
# 1305    81333.000000        Actualización Profesional     Virtual
# 1306    63233.000000        Actualización Profesional     Virtual
# 1307    56375.000000     Arte, Ciencias y Humanidades     Virtual
#
#                  Facultad  Exitoso2   Keywords
# 0                ECONOMIA         0   6.238095
# 1              INGENIERIA         0   6.977778
# 2              INGENIERIA         0   7.571429
# 3     ARTES Y HUMANIDADES         1  12.566667
# 4              INGENIERIA         0   6.977778
# ...                   ...       ...        ...
# 1303    CIENCIAS SOCIALES         0  26.714286
# 1304              DERECHO         0  50.285714
# 1305           INGENIERIA         0  18.375000
# 1306    CIENCIAS SOCIALES         1  19.071429
# 1307  ARTES Y HUMANIDADES         0   8.380952
#
# [1308 rows x 11 columns]

# %%
X['Keywords'] = X.Keywords.astype(float)

# %%
X['Keywords'].map('${:,.2f}'.format)
# Out:
# 0        $6.24
# 1        $6.98
# 2        $7.57
# 3       $12.57
# 4        $6.98
#          ...
# 1303    $26.71
# 1304    $50.29
# 1305    $18.38
# 1306    $19.07
# 1307     $8.38
# Name: Keywords, Length: 1308, dtype: object

# %%
X3 =X[['Curso.nuevo',	'Programa',	'NumCursos',	'NumCursosFac',	'Keywords',	'Valor.por.hora',	'Categoría',	'Modalidad',	'Facultad'	,'Exitoso2']]

# %%
X3['Keywords'] =X3['Keywords'].map('{:,.2f}'.format)
# Out:
# <ipython-input-10-00d27a68f645>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X3['Keywords'] =X3['Keywords'].map('{:,.2f}'.format)

# %%
X3['Valor.por.hora'] =X3['Valor.por.hora'].map('{:,.2f}'.format)
# Out:
# <ipython-input-11-71f4120b61bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X3['Valor.por.hora'] =X3['Valor.por.hora'].map('{:,.2f}'.format)

# %%
X3
# Out:
#       Curso.nuevo  Programa  NumCursos  NumCursosFac Keywords Valor.por.hora  \
# 0               0         1          6             1     6.24      45,000.00
# 1               1         1          6             4     6.98           0.00
# 2               1         1          6             4     7.57           0.00
# 3               1         1          6             1    12.57      64,951.43
# 4               0         1          6             4     6.98      37,500.00
# ...           ...       ...        ...           ...      ...            ...
# 1303            0         0         43             9    26.71      61,500.00
# 1304            0         0         43             4    50.29      71,281.00
# 1305            0         0         43             9    18.38      81,333.00
# 1306            0         0         43             9    19.07      63,233.00
# 1307            1         0         43             6     8.38      56,375.00
#
#                             Categoría   Modalidad             Facultad  \
# 0           Actualización Profesional  Presencial             ECONOMIA
# 1     Bienestar - Desarrollo Personal  Presencial           INGENIERIA
# 2     Bienestar - Desarrollo Personal  Presencial           INGENIERIA
# 3                     Niños y Jóvenes  Presencial  ARTES Y HUMANIDADES
# 4     Bienestar - Desarrollo Personal  Presencial           INGENIERIA
# ...                               ...         ...                  ...
# 1303        Actualización Profesional     Virtual    CIENCIAS SOCIALES
# 1304        Actualización Profesional     Virtual              DERECHO
# 1305        Actualización Profesional     Virtual           INGENIERIA
# 1306        Actualización Profesional     Virtual    CIENCIAS SOCIALES
# 1307     Arte, Ciencias y Humanidades     Virtual  ARTES Y HUMANIDADES
#
#       Exitoso2
# 0            0
# 1            0
# 2            0
# 3            1
# 4            0
# ...        ...
# 1303         0
# 1304         0
# 1305         0
# 1306         1
# 1307         0
#
# [1308 rows x 10 columns]

# %%
X3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1308 entries, 0 to 1307
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Curso.nuevo     1308 non-null   int64
#  1   Programa        1308 non-null   int64
#  2   NumCursos       1308 non-null   int64
#  3   NumCursosFac    1308 non-null   int64
#  4   Keywords        1308 non-null   object
#  5   Valor.por.hora  1308 non-null   object
#  6   Categoría       1308 non-null   object
#  7   Modalidad       1308 non-null   object
#  8   Facultad        1308 non-null   object
#  9   Exitoso2        1308 non-null   int64
# dtypes: int64(5), object(5)
# memory usage: 112.4+ KB

# %%
X3.to_csv('/content/Entrenamiento2.csv', sep=';', index=False)

# %%
# Eliminar filas completamente vacías
X=X.dropna()
features_col = ['Curso.nuevo', 'Programa', 'NumCursos', 'NumCursosFac', 'Keywords',
       'Valor.por.hora', 'Categoría', 'Modalidad', 'Facultad']
X_2 = X[features_col].copy()

y = X.Exitoso2
X = X.drop(columns=['Exitoso2'])

# %%
X_2
# Out:
#       Curso.nuevo  Programa  NumCursos  NumCursosFac   Keywords  \
# 0               0         1          6             1   6.238095
# 1               1         1          6             4   6.977778
# 2               1         1          6             4   7.571429
# 3               1         1          6             1  12.566667
# 4               0         1          6             4   6.977778
# ...           ...       ...        ...           ...        ...
# 1303            0         0         43             9  26.714286
# 1304            0         0         43             4  50.285714
# 1305            0         0         43             9  18.375000
# 1306            0         0         43             9  19.071429
# 1307            1         0         43             6   8.380952
#
#       Valor.por.hora                        Categoría   Modalidad  \
# 0       45000.000000        Actualización Profesional  Presencial
# 1           0.000000  Bienestar - Desarrollo Personal  Presencial
# 2           0.000000  Bienestar - Desarrollo Personal  Presencial
# 3       64951.430837                  Niños y Jóvenes  Presencial
# 4       37500.000000  Bienestar - Desarrollo Personal  Presencial
# ...              ...                              ...         ...
# 1303    61500.000000        Actualización Profesional     Virtual
# 1304    71281.000000        Actualización Profesional     Virtual
# 1305    81333.000000        Actualización Profesional     Virtual
# 1306    63233.000000        Actualización Profesional     Virtual
# 1307    56375.000000     Arte, Ciencias y Humanidades     Virtual
#
#                  Facultad
# 0                ECONOMIA
# 1              INGENIERIA
# 2              INGENIERIA
# 3     ARTES Y HUMANIDADES
# 4              INGENIERIA
# ...                   ...
# 1303    CIENCIAS SOCIALES
# 1304              DERECHO
# 1305           INGENIERIA
# 1306    CIENCIAS SOCIALES
# 1307  ARTES Y HUMANIDADES
#
# [1308 rows x 9 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1303    0
# 1304    0
# 1305    0
# 1306    1
# 1307    0
# Name: Exitoso2, Length: 1308, dtype: int64

# %%
# Dividir la base de datos en entrenamiento y prueba
random.seed(2022)
X_train, X_test, y_train, y_test = train_test_split(X_2, y, random_state=2022)
print (X_train)
# Out:
#       Curso.nuevo  Programa  NumCursos  NumCursosFac   Keywords  \
# 1257            1         0         69             5  29.071429
# 358             1         1         38             9   8.642857
# 1207            1         1         41             2  14.642857
# 965             1         1         43            13  52.642857
# 1152            1         1         35             2   2.678571
# ...           ...       ...        ...           ...        ...
# 240             1         1         57             2  12.571429
# 624             0         1         78             3   0.357143
# 173             1         1         43             9  21.428571
# 1244            0         1         39            10  27.333333
# 893             1         1         29             3  40.857143
#
#       Valor.por.hora                        Categoría   Modalidad  \
# 1257         60500.0        Actualización Profesional     Virtual
# 358          46865.0     Arte, Ciencias y Humanidades  Presencial
# 1207         56571.0        Actualización Profesional     Virtual
# 965          59321.0        Actualización Profesional     Virtual
# 1152         44000.0        Actualización Profesional  Presencial
# ...              ...                              ...         ...
# 240          54725.0        Actualización Profesional  Presencial
# 624          70000.0        Actualización Profesional     Virtual
# 173              0.0  Bienestar - Desarrollo Personal  Presencial
# 1244         23650.0     Arte, Ciencias y Humanidades     Virtual
# 893          53900.0        Actualización Profesional     Virtual
#
#                    Facultad
# 1257      CIENCIAS SOCIALES
# 358       CIENCIAS SOCIALES
# 1207               GOBIERNO
# 965       CIENCIAS SOCIALES
# 1152  ARQUITECTURA Y DISENO
# ...                     ...
# 240   ARQUITECTURA Y DISENO
# 624   ARQUITECTURA Y DISENO
# 173              INGENIERIA
# 1244      CIENCIAS SOCIALES
# 893                MEDICINA
#
# [981 rows x 9 columns]

# %% [markdown]
# ## Construcción modelo definitivo

# %%
#Transformacion OHE
ct = ColumnTransformer([('ohe', OneHotEncoder(handle_unknown = 'ignore'), ['Categoría', 'Modalidad', 'Facultad'])], remainder='passthrough')

# Clasificador
rfc = RandomForestClassifier(n_estimators=100, random_state = 2022)

# Construcción del pipeline
pipe = Pipeline([('ctransformer', ct), ('clf', rfc)])
pipe = pipe.fit(X_train,y_train)

# %%
pipe.score(X_test, y_test)
# Out:
# 0.7584097859327217

# %%
display(pipe)
# Out:
# Pipeline(steps=[('ctransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Categoría', 'Modalidad',
#                                                    'Facultad'])])),
#                 ('clf', RandomForestClassifier(random_state=2022))])

# %%
X_test.columns
# Out:
# Index(['Curso.nuevo', 'Programa', 'NumCursos', 'NumCursosFac', 'Keywords',
#        'Valor.por.hora', 'Categoría', 'Modalidad', 'Facultad'],
#       dtype='object')

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       222
#            1       0.64      0.55      0.59       105
#
#     accuracy                           0.76       327
#    macro avg       0.72      0.70      0.71       327
# weighted avg       0.75      0.76      0.75       327

# %%
pipe.steps[1][1].n_features_in_
# Out:
# 33

# %%
# predictions = pipe.predict_proba(base[features_col])
# base['probability_1'] = predictions[:, 1]
# df = base[['Curso.nuevo', 'Programa', 'NumCursos', 'NumCursosFac', 'Keywords',
#        'Valor.por.hora', 'Categoría', 'Modalidad', 'Facultad',
#        'Consecutivo.del.curso', 'Nombre.del.curso', 'probability_1', 'Exitoso2']]

# %%
# df.to_csv('/dbfs/mnt/analiticastorage_educacion-continua/99Prueba/Predicciones_Entrenamiento.csv', index=False, sep=';')

# %% [markdown]
# ## Plan Predicción nuevos registros

# %%
# %pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 47 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 40.6 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845512 sha256=faa27988cbab5b52b19cdb07cc028b6e1b732430bd8429a9e0be85450de38889
#   Stored in directory: /root/.cache/pip/wheels/43/dc/11/ec201cd671da62fa9c5cc77078235e40722170ceba231d7598
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.1

# %%
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.shell import spark
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 3.3.1
#       /_/
#
# Using Python version 3.8.16 (default, Dec  7 2022 01:12:13)
# Spark context Web UI available at http://67787b28efa9:4040
# Spark context available as 'sc' (master = local[*], app id = local-1671566050556).
# SparkSession available as 'spark'.

# %%
#Limpieza cache spark
spark.catalog.clearCache()

# %%
cat_df = spark.createDataFrame(X_test[['Facultad', 'Categoría', 'Modalidad']])
cat_df = cat_df.distinct()

# %%
#Importar utilidades de pyspark
import pyspark.sql.functions as F
from pyspark.sql.functions import udf
from pyspark.sql.types import FloatType

#Lectura cursos a predecir
predict_df = pd.read_csv('/content/EstructuraBaseTest.csv', delimiter=';', encoding='utf-8')
predict_df = spark.createDataFrame(predict_df)
for column in predict_df.columns:
  predict_df = predict_df.withColumnRenamed(column, column.replace('.', '_'))

# %%
#Casteo de fechas
predict_df = predict_df.withColumn('Fecha_creación', F.to_date(F.col('Fecha_creación'), 'dd/MM/yyyy'))
predict_df = predict_df.withColumn('Fecha_inicio', F.to_date(F.col('Fecha_inicio'), 'dd/MM/yyyy'))

#Casteo de decimales
predict_df = predict_df.withColumn('Valor_por_hora', F.regexp_replace(F.col('Valor_por_hora'), ',', '.').cast('float'))

#Agregar ventanas de tiempo
predict_df = predict_df.withColumn('Fecha_busqueda', F.add_months(F.col('Fecha_creación'), -1))
predict_df = predict_df.withColumn('Fecha_ventana', F.add_months(F.col('Fecha_creación'), -6))

# %%
#Separación de keywords
predict_df = predict_df.withColumn('Keywords', F.regexp_replace(F.col('Keywords'), r',\s', ','))
predict_df = predict_df.withColumn('Keywords', F.split(F.col('Keywords'), ','))
predict_df = predict_df.withColumn('Keywords', F.array_remove(F.col('Keywords'), ''))

# %%
predict_df = predict_df.cache()
predict_df.count()
# Out:
# 96

# %%
#Completar información con pytrens - Google Trends
def get_google_trend(keywords, start_date, end_date):
  print(keywords)
  start_date_str = start_date.strftime('%Y-%m-%d')
  end_date_str = end_date.strftime('%Y-%m-%d')
  #Establecemos una variable lista que incluye la palabra o palabras que queremos analizar para nuesto caso una lista 
  keywords_list = list(keywords)
  keywords_list = [kw.lower().strip().replace(r'[^\w\s]', '') for kw in keywords_list]
  
  print(keywords_list)
  df = None
  max_tol = 30
  init_tol = 1
  #Conectamos con Google Trends y pasamos unos parámetros base
  pytrend = TrendReq(hl='su', tz=360, geo='CO')
  try:
    #Agregamos todos los parámetros que queramos a la solicitud (filtrados)
    pytrend.build_payload(keywords_list[:5], timeframe=f'{start_date_str} {end_date_str}', cat=958)
    df = pytrend.interest_over_time().drop(['isPartial'],axis=1)
  except:
    request_success = False
    while (not request_success) and (init_tol < max_tol):
      time.sleep(1+round(random.random(), 2))
      try:
        pytrend.build_payload(keywords_list[:5], timeframe=f'{start_date_str} {end_date_str}', cat=958)
        df = pytrend.interest_over_time().drop(['isPartial'],axis=1)
        request_success = True
      except:
        request_success = False
        init_tol = init_tol + 1
  if df is None:
    return 0
  means = df.mean()
  return round(float(means.mean()), 2)

# %%
df_rows = predict_df.collect()

# %%
predict_df = predict_df.withColumn('Keywords_gt', F.lit(0))
for row in df_rows:
  keywords = get_google_trend(row['Keywords'], row['Fecha_busqueda'], row['Fecha_creación'])
  predict_df = predict_df.withColumn('Keywords_gt', F.when(F.col('Consectutivo curso') == row['Consectutivo curso'], keywords).otherwise(F.col('Keywords_gt')))
# Out:
# ['arquitectura', 'arquitectos', 'bim', 'arquitectura interior', 'Procedimientos BIM para el diseño de arquitectura interior']
# ['arquitectura', 'arquitectos', 'bim', 'arquitectura interior', 'procedimientos bim para el diseño de arquitectura interior']
# ['Design Thinking', 'innovación']
# ['design thinking', 'innovación']
# ['Proyectos', 'proyectos inmobiliarios', 'arquitectura', 'diseño']
# ['proyectos', 'proyectos inmobiliarios', 'arquitectura', 'diseño']
# ['taller de  pintura', 'clases de dibujo', 'aprender a pintar']
# ['taller de  pintura', 'clases de dibujo', 'aprender a pintar']
# ['periodismo', 'cursos periodismo', 'narración periodística', 'Lecturas', 'piezas audiovisuales', 'historias periodísticas.']
# ['periodismo', 'cursos periodismo', 'narración periodística', 'lecturas', 'piezas audiovisuales', 'historias periodísticas.']
# ['arte', 'historia del arte', 'apreciacion del arte', 'artes']
# ['arte', 'historia del arte', 'apreciacion del arte', 'artes']
# ['Artistas', 'cultura', 'historia del arte', 'arte', 'colecciones públicas.']
# ['artistas', 'cultura', 'historia del arte', 'arte', 'colecciones públicas.']
# ['escritura', 'ortografia', 'artes', 'escritor', 'escribir', 'estilo']
# ['escritura', 'ortografia', 'artes', 'escritor', 'escribir', 'estilo']
# ['Escritura', 'narrativas', 'artes', 'literatura', 'narrativas']
# ['escritura', 'narrativas', 'artes', 'literatura', 'narrativas']
# ['Poesía', 'narrativas', 'lietratura', 'artes y humanidades']
# ['poesía', 'narrativas', 'lietratura', 'artes y humanidades']
# ['Macrocredencial', 'curso', 'taller', 'territorio', 'planificación territorial', 'planificación', 'enfoque territorial', 'desarrollo territorial', 'ordenamiento territorial']
# ['macrocredencial', 'curso', 'taller', 'territorio', 'planificación territorial', 'planificación', 'enfoque territorial', 'desarrollo territorial', 'ordenamiento territorial']
# ['Dirección política', 'Tierras. ordenamiento territorial', 'gestión catastral']
# ['dirección política', 'tierras. ordenamiento territorial', 'gestión catastral']
# ['Acueductos', 'Social', 'Acueductos comunitarios', 'Sustentabilidad', 'territorio']
# ['acueductos', 'social', 'acueductos comunitarios', 'sustentabilidad', 'territorio']
# ['Fundraising', 'iniciativas sociales y ambientales']
# ['fundraising', 'iniciativas sociales y ambientales']
# ['Desarrollo de proyectos', 'proyectos electrónicos']
# ['desarrollo de proyectos', 'proyectos electrónicos']
# ['Cohetería', 'astronomía', 'planetas', 'niños', 'planetaria para jugar']
# ['cohetería', 'astronomía', 'planetas', 'niños', 'planetaria para jugar']
# ['astronomía', 'astronomía planetaria', 'planetas', 'órbitas', 'jóvenes', 'ciencias', 'espaciales', 'espacio', 'telescopios', 'sistema solar', 'sol', 'curso', 'conocimiento']
# ['astronomía', 'astronomía planetaria', 'planetas', 'órbitas', 'jóvenes', 'ciencias', 'espaciales', 'espacio', 'telescopios', 'sistema solar', 'sol', 'curso', 'conocimiento']
# ['astronimía', 'astronomia', 'astros', 'contelaciones', 'estrellas', 'telescopio', 'cuerpos celestes']
# ['astronimía', 'astronomia', 'astros', 'contelaciones', 'estrellas', 'telescopio', 'cuerpos celestes']
# ['Desarrollo de proyectos', 'proyectos electrónicos']
# ['desarrollo de proyectos', 'proyectos electrónicos']
# ['Sistemas de información geográfica en salud pública']
# ['sistemas de información geográfica en salud pública']
# ['Sector hidrocarburos', 'Transición Energética']
# ['sector hidrocarburos', 'transición energética']
# ['Analítica de datos', 'Teoría de Grafos', 'datos']
# ['analítica de datos', 'teoría de grafos', 'datos']
# ['Inteligencia emocional', 'psicología', 'conocimiento', 'autoconocimiento y autocuidado']
# ['inteligencia emocional', 'psicología', 'conocimiento', 'autoconocimiento y autocuidado']
# ['Habilidades personales', 'ciencias sociales', 'liderazgo', 'gerencia', 'habilidades profesionales']
# ['habilidades personales', 'ciencias sociales', 'liderazgo', 'gerencia', 'habilidades profesionales']
# ['Liderazgo', 'habilidades gerenciales', 'desarollo de competencias', 'ciencias sociales']
# ['liderazgo', 'habilidades gerenciales', 'desarollo de competencias', 'ciencias sociales']
# ['intervención social', 'programas sociales', 'sostenibilidad', 'colombia']
# ['intervención social', 'programas sociales', 'sostenibilidad', 'colombia']
# ['nutrición', 'nutricion', 'emociones', 'psicologia', 'nutrición y emoción', 'alimentación saludable', 'vida saludable']
# ['nutrición', 'nutricion', 'emociones', 'psicologia', 'nutrición y emoción', 'alimentación saludable', 'vida saludable']
# ['Liderazgo', ' habilidades gerenciales', 'habilidades personales']
# ['liderazgo', 'habilidades gerenciales', 'habilidades personales']
# ['Liderazgo', 'habilidades sistémicas y habilidades gerenciales']
# ['liderazgo', 'habilidades sistémicas y habilidades gerenciales']
# ['Liderazgo', 'ser Líder', 'desarrollo personal', 'ciencias sociales', 'psicología']
# ['liderazgo', 'ser líder', 'desarrollo personal', 'ciencias sociales', 'psicología']
# ['Guerra fría', 'Putin', 'sociedad rusa', 'historia', 'ciencias sociales']
# ['guerra fría', 'putin', 'sociedad rusa', 'historia', 'ciencias sociales']
# ['proyectos etnográficos', 'etnografía', 'metodologías creativas', 'ciencias sociales']
# ['proyectos etnográficos', 'etnografía', 'metodologías creativas', 'ciencias sociales']
# ['Investigación', 'tendencias de investigación', 'Ciencias Sociales']
# ['investigación', 'tendencias de investigación', 'ciencias sociales']
# ['Niñez', 'desarrollo niños', 'desarrollo socioemocional', 'mindfulness']
# ['niñez', 'desarrollo niños', 'desarrollo socioemocional', 'mindfulness']
# ['Investigación', 'investigación digital', 'análisis etnográfico', 'ciencias sociales']
# ['investigación', 'investigación digital', 'análisis etnográfico', 'ciencias sociales']
# ['Inteligencia emocional', 'manejo de emociones', 'emociones', 'ser humano']
# ['inteligencia emocional', 'manejo de emociones', 'emociones', 'ser humano']
# ['Habilidades personales', 'ciencias sociales', 'liderazgo', 'gerencia', 'habilidades profesionales']
# ['habilidades personales', 'ciencias sociales', 'liderazgo', 'gerencia', 'habilidades profesionales']
# ['Ciencias sociales', 'Psicología', 'autoconocimiento', 'habilidades personales.']
# ['ciencias sociales', 'psicología', 'autoconocimiento', 'habilidades personales.']
# ['Habilidades clínicas', 'CBT', 'FAP', 'Habilidades Conceptuales', 'modelos de supervisión', 'Terapia Cognitivo Conductual', 'Psicoterapia Analítico Funcional', 'métodos conductuales', 'cognitivo-conductuales.']
# ['habilidades clínicas', 'cbt', 'fap', 'habilidades conceptuales', 'modelos de supervisión', 'terapia cognitivo conductual', 'psicoterapia analítico funcional', 'métodos conductuales', 'cognitivo-conductuales.']
# ['educacion', 'formadores', 'capacitadores', 'coach', 'crecimiento personal', 'competencias', 'profesionales']
# ['educacion', 'formadores', 'capacitadores', 'coach', 'crecimiento personal', 'competencias', 'profesionales']
# ['violencia', 'conflicto armado', 'guerra', 'derechos humanos', 'sociales']
# ['violencia', 'conflicto armado', 'guerra', 'derechos humanos', 'sociales']
# ['Niñez', 'desarrollo niños', 'desarrollo socioemocional', 'mindfulness']
# ['niñez', 'desarrollo niños', 'desarrollo socioemocional', 'mindfulness']
# ['Inteligencia emocional', 'autocuidado', 'ser humano', 'emociones.']
# ['inteligencia emocional', 'autocuidado', 'ser humano', 'emociones.']
# ['Liderazgo', ' habilidades gerenciales', 'habilidades personales']
# ['liderazgo', 'habilidades gerenciales', 'habilidades personales']
# ['Liderazgo', 'habilidades personales y habilidades gerenciales']
# ['liderazgo', 'habilidades personales y habilidades gerenciales']
# ['politicas publicas', 'intervencion social', 'sotenibilidad', 'conflicto interno', 'corrupcion']
# ['politicas publicas', 'intervencion social', 'sotenibilidad', 'conflicto interno', 'corrupcion']
# ['Manejo creativo de la ansiedad', 'Inteligencia emocional', 'ansiedad', 'emociones']
# ['manejo creativo de la ansiedad', 'inteligencia emocional', 'ansiedad', 'emociones']
# ['Liderazgo', 'habilidades interpersonales', 'comunicación y habilidades gerenciales']
# ['liderazgo', 'habilidades interpersonales', 'comunicación y habilidades gerenciales']
# ['ruralidad', 'social', 'intervención', 'politicas publicas. sostenibilidad']
# ['ruralidad', 'social', 'intervención', 'politicas publicas. sostenibilidad']
# ['Liderazgo', 'habilidades interpersonales y habilidades gerenciales']
# ['liderazgo', 'habilidades interpersonales y habilidades gerenciales']
# ['Derecho', 'Abogados', 'Infraestructura', 'Regulación y Financiamiento']
# ['derecho', 'abogados', 'infraestructura', 'regulación y financiamiento']
# ['Protección', 'datos', 'derecho', 'abogados', 'datos', 'accountability']
# ['protección', 'datos', 'derecho', 'abogados', 'datos', 'accountability']
# ['Transacciones corporativas', 'Derecho', 'M&A', 'Legal', 'Banca de inversión']
# ['transacciones corporativas', 'derecho', 'm&a', 'legal', 'banca de inversión']
# ['Derecho. abogados', 'Marítimo']
# ['derecho. abogados', 'marítimo']
# ['Derecho Laboral', 'derecho', 'leyes', 'abogados', 'nuevas tendencias de derecho']
# ['derecho laboral', 'derecho', 'leyes', 'abogados', 'nuevas tendencias de derecho']
# ['Derecho', 'abogados', 'entretenimiento']
# ['derecho', 'abogados', 'entretenimiento']
# ['Energías renovables', 'derecho', 'abogados']
# ['energías renovables', 'derecho', 'abogados']
# ['Escritura Jurídica', ' Derecho', 'Problemas Jurídicos', 'Texto Argumentativo']
# ['escritura jurídica', 'derecho', 'problemas jurídicos', 'texto argumentativo']
# ['Legal English', 'Business', 'Derecho', 'Abogados']
# ['legal english', 'business', 'derecho', 'abogados']
# ['Actualización profesional', 'contratación Estatal', 'emprendimiento', 'tecnología e innovación.']
# ['actualización profesional', 'contratación estatal', 'emprendimiento', 'tecnología e innovación.']
# ['Derecho', 'Régimen', 'Insolvencia']
# ['derecho', 'régimen', 'insolvencia']
# ['derechos', 'derechos humanos', 'derecho internacional', 'paz', 'contruccion de paz', 'derecho internacional humanitario', 'negociaciones de paz']
# ['derechos', 'derechos humanos', 'derecho internacional', 'paz', 'contruccion de paz', 'derecho internacional humanitario', 'negociaciones de paz']
# ['Compliance', 'SAGRILAFT', 'PTEE', 'derecho']
# ['compliance', 'sagrilaft', 'ptee', 'derecho']
# ['Escritura Jurídica', ' Derecho', 'Problemas Jurídicos', 'Texto Argumentativo']
# ['escritura jurídica', 'derecho', 'problemas jurídicos', 'texto argumentativo']
# ['Finanzas', 'abogados', 'derecho']
# ['finanzas', 'abogados', 'derecho']
# ['Método KonMari™: felicidad y bienestar', 'Japón', 'cultura japonesa']
# ['método konmari™: felicidad y bienestar', 'japón', 'cultura japonesa']
# ['Historia antigua de Japón', 'cursos de historia', 'historia de japón', 'japón']
# ['historia antigua de japón', 'cursos de historia', 'historia de japón', 'japón']
# ['Método KonMari™: felicidad y bienestar', 'Japón', 'cultura japonesa']
# ['método konmari™: felicidad y bienestar', 'japón', 'cultura japonesa']
# ['Filosofía Japonesa', 'Cultura Japonesa', 'Retos Japón']
# ['filosofía japonesa', 'cultura japonesa', 'retos japón']
# ['Analítica', 'Python', 'Economía', 'Negocio', 'Problemas reales.']
# ['analítica', 'python', 'economía', 'negocio', 'problemas reales.']
# ['Analítica', 'Python', 'Economía', 'Negocio', 'Problemas reales.']
# ['analítica', 'python', 'economía', 'negocio', 'problemas reales.']
# ['Finanzas cuantitativas en R', 'economía']
# ['finanzas cuantitativas en r', 'economía']
# ['Evaluación economica', 'financiera', 'inversión']
# ['evaluación economica', 'financiera', 'inversión']
# ['finanzas', 'emprendimiento', 'economía', 'emprendedores', 'finanzas básicas']
# ['finanzas', 'emprendimiento', 'economía', 'emprendedores', 'finanzas básicas']
# ['Analítica', 'Python', 'Economía', 'Negocio', 'Problemas reales.']
# ['analítica', 'python', 'economía', 'negocio', 'problemas reales.']
# ['Datos', 'Economía', 'Analítica', 'Operaciones Matemáticas', 'Matemática']
# ['datos', 'economía', 'analítica', 'operaciones matemáticas', 'matemática']
# ['mercados capitales', 'curso', 'taller', 'análisis de datos', 'cursos de economía', 'cursos de análisis de datos']
# ['mercados capitales', 'curso', 'taller', 'análisis de datos', 'cursos de economía', 'cursos de análisis de datos']
# ['Machine Learning', 'Business', 'Resultados', 'Python', 'Analítica', 'Economía']
# ['machine learning', 'business', 'resultados', 'python', 'analítica', 'economía']
# ['Bolsa', 'Inversiones', 'Economía', 'Riesgo de pérdida.']
# ['bolsa', 'inversiones', 'economía', 'riesgo de pérdida.']
# ['Valoración', 'Económica', 'Ambiental', 'política', 'pública', 'políticas públicasproblemas ambientalespolíticas públicas ambientales']
# ['valoración', 'económica', 'ambiental', 'política', 'pública', 'políticas públicasproblemas ambientalespolíticas públicas ambientales']
# ['Big data', 'machine learning', 'inmobiliarias', 'sector inmobiliario', 'curso', 'taller', 'análisis de datos']
# ['big data', 'machine learning', 'inmobiliarias', 'sector inmobiliario', 'curso', 'taller', 'análisis de datos']
# ['Optimización', 'Portafolios', 'Derivados Financieros']
# ['optimización', 'portafolios', 'derivados financieros']
# ['Datos', 'Economía', 'Analítica', 'Operaciones Matemáticas', 'Matemática']
# ['datos', 'economía', 'analítica', 'operaciones matemáticas', 'matemática']
# ['Ambientes virtuales', 'educación', 'aprendizaje']
# ['ambientes virtuales', 'educación', 'aprendizaje']
# ['Pronunciation', 'Matters', 'Teaching', 'English', 'pronunciation', 'communicatively']
# ['pronunciation', 'matters', 'teaching', 'english', 'pronunciation', 'communicatively']
# ['gamificación educativaestrategias ludicas diseño de juegos']
# ['gamificación educativaestrategias ludicas diseño de juegos']
# ['Excel. manejo de excel', 'ingenieria', 'toma de  Decisiones']
# ['excel. manejo de excel', 'ingenieria', 'toma de  decisiones']
# ['Gerencia de Proyectos']
# ['gerencia de proyectos']
# ['Educación', 'Ingeniería']
# ['educación', 'ingeniería']
# ['cannabis medicinal curso cannabis', 'cannabis medicinal', 'usos del cannabis', 'cannabis cannabis medicinalcultivo de cannabis']
# ['cannabis medicinal curso cannabis', 'cannabis medicinal', 'usos del cannabis', 'cannabis cannabis medicinalcultivo de cannabis']
# ['Educación', 'Ingeniería']
# ['educación', 'ingeniería']
# ['Programación', 'Python', 'manipulación', 'visualización de datos', 'Pandas y Matplotlib']
# ['programación', 'python', 'manipulación', 'visualización de datos', 'pandas y matplotlib']
# ['Impresión', 'ingeniería', 'bioimpresión 3D en salud']
# ['impresión', 'ingeniería', 'bioimpresión 3d en salud']
# ['Hidrógeno', 'hoja de ruta', 'gerencia de proyecto', 'eficiencia energética', 'sostenibilidad', 'energías renovables', 'potencial energético', 'cadena de valor', 'vector energético', 'innovación y desarrollo', 'producción y consumo.']
# ['hidrógeno', 'hoja de ruta', 'gerencia de proyecto', 'eficiencia energética', 'sostenibilidad', 'energías renovables', 'potencial energético', 'cadena de valor', 'vector energético', 'innovación y desarrollo', 'producción y consumo.']
# ['Fundamentos Anatómicos', 'fundamentos fisiológicos', 'acupuntura', 'medicina']
# ['fundamentos anatómicos', 'fundamentos fisiológicos', 'acupuntura', 'medicina']
# ['cursos de medicina', 'medicina alternativa', 'medicina tradicional', 'anatomía quirúrgica.']
# ['cursos de medicina', 'medicina alternativa', 'medicina tradicional', 'anatomía quirúrgica.']

# %%
predict_df = (
  predict_df
  .withColumn('Keywords_list', F.array_join(F.col('Keywords'), ', '))
  .withColumn('Keywords', F.col('Keywords_gt'))
  .withColumn('Curso_nuevo', F.when(F.col('Curso_nuevo') == 'Si', 1).otherwise(0))
  .withColumn('Programa', F.when(F.col('Programa') == 'Si', 1).otherwise(0))
  .select(
    F.col('Curso_nuevo').alias('Curso.nuevo'), 
    F.col('Programa'),
    F.col('NumCursos'), 
    F.col('NumCursosFac'), 
    F.col('Keywords'),
    F.col('Valor_por_hora').alias('Valor.por.hora'), 
    F.col('Categoría'),
    F.col('Modalidad'), 
    F.col('Facultad'), 
    F.col('Consectutivo curso'),
    F.col('Keywords_list'), F.col('Nombre')
  )
)

# %%
display(predict_df)
# Out:
# DataFrame[Curso.nuevo: int, Programa: int, NumCursos: bigint, NumCursosFac: bigint, Keywords: double, Valor.por.hora: float, Categoría: string, Modalidad: string, Facultad: string, Consectutivo curso: string, Keywords_list: string, Nombre: string]

# %%
predict_df
# Out:
# DataFrame[Curso.nuevo: int, Programa: int, NumCursos: bigint, NumCursosFac: bigint, Keywords: double, Valor.por.hora: float, Categoría: string, Modalidad: string, Facultad: string, Consectutivo curso: string, Keywords_list: string, Nombre: string]

# %%
predict_df = predict_df.toPandas()
df_to_predict = predict_df[features_col]

# %%
predict_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Curso.nuevo         96 non-null     int32
#  1   Programa            96 non-null     int32
#  2   NumCursos           96 non-null     int64
#  3   NumCursosFac        96 non-null     int64
#  4   Keywords            96 non-null     float64
#  5   Valor.por.hora      96 non-null     float32
#  6   Categoría           96 non-null     object
#  7   Modalidad           96 non-null     object
#  8   Facultad            96 non-null     object
#  9   Consectutivo curso  96 non-null     object
#  10  Keywords_list       96 non-null     object
#  11  Nombre              96 non-null     object
# dtypes: float32(1), float64(1), int32(2), int64(2), object(6)
# memory usage: 8.0+ KB

# %%
predict_df
# Out:
#     Curso.nuevo  Programa  NumCursos  NumCursosFac  Keywords  Valor.por.hora  \
# 0             1         0         61             4     11.33    48888.890625
# 1             1         0         61             5     12.89    52083.328125
# 2             0         0         69             3     18.98    58043.750000
# 3             1         1         30             3     11.94    43750.000000
# 4             1         1         30             3      5.70    37000.000000
# ..          ...       ...        ...           ...       ...             ...
# 91            1         0         61            12     14.64    16444.439453
# 92            1         0         61            12     11.36    71875.000000
# 93            1         0         69             5      7.15    81481.476562
# 94            0         0         68             1     18.90    38888.890625
# 95            1         0         68             1      7.21   312500.000000
#
#                        Categoría                 Modalidad  \
# 0      Actualización Profesional                   Virtual
# 1      Actualización Profesional                   Virtual
# 2      Actualización Profesional                   Virtual
# 3   Arte, Ciencias y Humanidades                Presencial
# 4      Actualización Profesional  Semipresencial / Blended
# ..                           ...                       ...
# 91     Actualización Profesional                   Virtual
# 92     Actualización Profesional  Semipresencial / Blended
# 93     Actualización Profesional  Semipresencial / Blended
# 94     Actualización Profesional                   Virtual
# 95     Actualización Profesional                Presencial
#
#                  Facultad Consectutivo curso  \
# 0   ARQUITECTURA Y DISENO        CUR-0038024
# 1   ARQUITECTURA Y DISENO        CUR-0038228
# 2   ARQUITECTURA Y DISENO        CUR-0038441
# 3     ARTES Y HUMANIDADES        CUR-0037833
# 4     ARTES Y HUMANIDADES        CUR-0037838
# ..                    ...                ...
# 91             INGENIERIA        CUR-0038427
# 92             INGENIERIA        CUR-0038359
# 93             INGENIERIA        CUR-0039407
# 94               MEDICINA        CUR-0038216
# 95               MEDICINA        CUR-0038400
#
#                                         Keywords_list  \
# 0   arquitectura, arquitectos, bim, arquitectura i...
# 1                         Design Thinking, innovación
# 2   Proyectos, proyectos inmobiliarios, arquitectu...
# 3   taller de  pintura, clases de dibujo, aprender...
# 4   periodismo, cursos periodismo, narración perio...
# ..                                                ...
# 91  Programación, Python, manipulación, visualizac...
# 92    Impresión, ingeniería, bioimpresión 3D en salud
# 93  Hidrógeno, hoja de ruta, gerencia de proyecto,...
# 94  Fundamentos Anatómicos, fundamentos fisiológic...
# 95  cursos de medicina, medicina alternativa, medi...
#
#                                                Nombre
# 0   Metodología de diseño y procesos BIM para la a...
# 1   Metodologías de Design Thinking para la innova...
# 2   Herramientas para formular proyectos inmobilia...
# 3                                             Pintura
# 4                           Periodismo y Storytelling
# ..                                                ...
# 91  Aprende a programar en Python: de los principi...
# 92               Impresión y bioimpresión 3D en salud
# 93  Hidrógeno (H2): Ciencia, tecnología y formulac...
# 94  Fundamentos Anatómicos y Fisiológicos en Acupu...
# 95  Curso hueso temporal y cirugía endoscópica de ...
#
# [96 rows x 12 columns]

# %%
predict_df.to_csv('/content/predecir.csv', sep=';', index=False)

# %%
predictions = pipe.predict_proba(df_to_predict)

# %%
display(predict_df)
# Out:
#     Curso.nuevo  Programa  NumCursos  NumCursosFac  Keywords  Valor.por.hora  \
# 0             1         0         61             4     11.33    48888.890625
# 1             1         0         61             5     12.89    52083.328125
# 2             0         0         69             3     18.98    58043.750000
# 3             1         1         30             3     11.94    43750.000000
# 4             1         1         30             3      5.70    37000.000000
# ..          ...       ...        ...           ...       ...             ...
# 91            1         0         61            12     14.64    16444.439453
# 92            1         0         61            12     11.36    71875.000000
# 93            1         0         69             5      7.15    81481.476562
# 94            0         0         68             1     18.90    38888.890625
# 95            1         0         68             1      7.21   312500.000000
#
#                        Categoría                 Modalidad  \
# 0      Actualización Profesional                   Virtual
# 1      Actualización Profesional                   Virtual
# 2      Actualización Profesional                   Virtual
# 3   Arte, Ciencias y Humanidades                Presencial
# 4      Actualización Profesional  Semipresencial / Blended
# ..                           ...                       ...
# 91     Actualización Profesional                   Virtual
# 92     Actualización Profesional  Semipresencial / Blended
# 93     Actualización Profesional  Semipresencial / Blended
# 94     Actualización Profesional                   Virtual
# 95     Actualización Profesional                Presencial
#
#                  Facultad Consectutivo curso  \
# 0   ARQUITECTURA Y DISENO        CUR-0038024
# 1   ARQUITECTURA Y DISENO        CUR-0038228
# 2   ARQUITECTURA Y DISENO        CUR-0038441
# 3     ARTES Y HUMANIDADES        CUR-0037833
# 4     ARTES Y HUMANIDADES        CUR-0037838
# ..                    ...                ...
# 91             INGENIERIA        CUR-0038427
# 92             INGENIERIA        CUR-0038359
# 93             INGENIERIA        CUR-0039407
# 94               MEDICINA        CUR-0038216
# 95               MEDICINA        CUR-0038400
#
#                                         Keywords_list  \
# 0   arquitectura, arquitectos, bim, arquitectura i...
# 1                         Design Thinking, innovación
# 2   Proyectos, proyectos inmobiliarios, arquitectu...
# 3   taller de  pintura, clases de dibujo, aprender...
# 4   periodismo, cursos periodismo, narración perio...
# ..                                                ...
# 91  Programación, Python, manipulación, visualizac...
# 92    Impresión, ingeniería, bioimpresión 3D en salud
# 93  Hidrógeno, hoja de ruta, gerencia de proyecto,...
# 94  Fundamentos Anatómicos, fundamentos fisiológic...
# 95  cursos de medicina, medicina alternativa, medi...
#
#                                                Nombre
# 0   Metodología de diseño y procesos BIM para la a...
# 1   Metodologías de Design Thinking para la innova...
# 2   Herramientas para formular proyectos inmobilia...
# 3                                             Pintura
# 4                           Periodismo y Storytelling
# ..                                                ...
# 91  Aprende a programar en Python: de los principi...
# 92               Impresión y bioimpresión 3D en salud
# 93  Hidrógeno (H2): Ciencia, tecnología y formulac...
# 94  Fundamentos Anatómicos y Fisiológicos en Acupu...
# 95  Curso hueso temporal y cirugía endoscópica de ...
#
# [96 rows x 12 columns]

# %%
predict_df['probability_1'] = predictions[:, 1]

# %%
#Predicho
display(predict_df)
# Out:
#     Curso.nuevo  Programa  NumCursos  NumCursosFac  Keywords  Valor.por.hora  \
# 0             1         0         61             4     11.33    48888.890625
# 1             1         0         61             5     12.89    52083.328125
# 2             0         0         69             3     18.98    58043.750000
# 3             1         1         30             3     11.94    43750.000000
# 4             1         1         30             3      5.70    37000.000000
# ..          ...       ...        ...           ...       ...             ...
# 91            1         0         61            12     14.64    16444.439453
# 92            1         0         61            12     11.36    71875.000000
# 93            1         0         69             5      7.15    81481.476562
# 94            0         0         68             1     18.90    38888.890625
# 95            1         0         68             1      7.21   312500.000000
#
#                        Categoría                 Modalidad  \
# 0      Actualización Profesional                   Virtual
# 1      Actualización Profesional                   Virtual
# 2      Actualización Profesional                   Virtual
# 3   Arte, Ciencias y Humanidades                Presencial
# 4      Actualización Profesional  Semipresencial / Blended
# ..                           ...                       ...
# 91     Actualización Profesional                   Virtual
# 92     Actualización Profesional  Semipresencial / Blended
# 93     Actualización Profesional  Semipresencial / Blended
# 94     Actualización Profesional                   Virtual
# 95     Actualización Profesional                Presencial
#
#                  Facultad Consectutivo curso  \
# 0   ARQUITECTURA Y DISENO        CUR-0038024
# 1   ARQUITECTURA Y DISENO        CUR-0038228
# 2   ARQUITECTURA Y DISENO        CUR-0038441
# 3     ARTES Y HUMANIDADES        CUR-0037833
# 4     ARTES Y HUMANIDADES        CUR-0037838
# ..                    ...                ...
# 91             INGENIERIA        CUR-0038427
# 92             INGENIERIA        CUR-0038359
# 93             INGENIERIA        CUR-0039407
# 94               MEDICINA        CUR-0038216
# 95               MEDICINA        CUR-0038400
#
#                                         Keywords_list  \
# 0   arquitectura, arquitectos, bim, arquitectura i...
# 1                         Design Thinking, innovación
# 2   Proyectos, proyectos inmobiliarios, arquitectu...
# 3   taller de  pintura, clases de dibujo, aprender...
# 4   periodismo, cursos periodismo, narración perio...
# ..                                                ...
# 91  Programación, Python, manipulación, visualizac...
# 92    Impresión, ingeniería, bioimpresión 3D en salud
# 93  Hidrógeno, hoja de ruta, gerencia de proyecto,...
# 94  Fundamentos Anatómicos, fundamentos fisiológic...
# 95  cursos de medicina, medicina alternativa, medi...
#
#                                                Nombre  probability_1
# 0   Metodología de diseño y procesos BIM para la a...           0.41
# 1   Metodologías de Design Thinking para la innova...           0.38
# 2   Herramientas para formular proyectos inmobilia...           0.68
# 3                                             Pintura           0.27
# 4                           Periodismo y Storytelling           0.19
# ..                                                ...            ...
# 91  Aprende a programar en Python: de los principi...           0.52
# 92               Impresión y bioimpresión 3D en salud           0.34
# 93  Hidrógeno (H2): Ciencia, tecnología y formulac...           0.30
# 94  Fundamentos Anatómicos y Fisiológicos en Acupu...           0.60
# 95  Curso hueso temporal y cirugía endoscópica de ...           0.28
#
# [96 rows x 13 columns]

# %%
predict_df.to_csv('/content/Predicciones_sin.csv', sep=';', index=False)

# %%
#Predicciones base de entrenamiento y validacion
base_df = base[list(X_2.columns) + ['Consecutivo.del.curso', 'Nombre.del.curso', 'Exitoso2']]
base_df = base_df.dropna()
predicciones = pipe.predict_proba(base_df[X_2.columns])
base_df['probability_1'] = predicciones[:, 1]

# %%
base_df.to_csv('/content/Predicciones_Entrenamiento_sin.csv', sep=';', index=False)

# %%
def make_keywords(x):
  x_list = list(x)
  x_list = [i for i in x_list if not isinstance(i, float)]
  return ', '.join(x_list)

# %%
base['Keywords_org'] = base[[f'kw{i+1}' for i in range(5)]].apply(make_keywords, axis=1)
columns_to_take = features_col + ['Fecha.de.inicio', 'Fecha.de.creación', 'Keywords_org', 'Consecutivo.del.curso', 'Exitoso2', 'Nombre.del.curso'] + [f'kw{i+1}' for i in range(5)]
exitosos = base[(base['Exitoso2'] == 1) & (base['Valor.por.hora'].notna())][columns_to_take].head()
no_exitosos = base[(base['Exitoso2'] == 0) & (base['Valor.por.hora'].notna())][columns_to_take].head()
df_to_append = pd.concat([exitosos, no_exitosos])

# %%
#Original
predictions = pipe.predict_proba(df_to_append[features_col])
df_to_append['probability_1'] = predictions[:, 1]
display(df_to_append[features_col + ['Consecutivo.del.curso', 'Nombre.del.curso', 'probability_1']])
# Out:
#     Curso.nuevo  Programa  NumCursos  NumCursosFac   Keywords  Valor.por.hora  \
# 5             1         1          6             4   7.571429        136364.0
# 7             1         1         23            10   1.071429         71188.0
# 12            0         1         23             1  12.828571         87083.0
# 14            1         1         23             1   7.476190         70125.0
# 15            1         1         23             3   8.178571         48667.0
# 0             0         1          6             1   6.238095         45000.0
# 1             1         1          6             4   6.977778             0.0
# 2             1         1          6             4   7.571429             0.0
# 4             0         1          6             4   6.977778         37500.0
# 6             1         1         23            10   1.071429         75000.0
#
#                           Categoría   Modalidad  \
# 5   Bienestar - Desarrollo Personal  Presencial
# 7                   Niños y Jóvenes  Presencial
# 12        Actualización Profesional  Presencial
# 14        Actualización Profesional  Presencial
# 15        Actualización Profesional  Presencial
# 0         Actualización Profesional  Presencial
# 1   Bienestar - Desarrollo Personal  Presencial
# 2   Bienestar - Desarrollo Personal  Presencial
# 4   Bienestar - Desarrollo Personal  Presencial
# 6                   Niños y Jóvenes  Presencial
#
#                                              Facultad Consecutivo.del.curso  \
# 5                                          INGENIERIA           CUR-0018294
# 7                                 ARTES Y HUMANIDADES           CUR-0018847
# 12                                              CIDER           CUR-0018513
# 14  CENTRO DE SERVICIOS INTEGRALES EN GENETICA - S...           CUR-0018672
# 15                                           MEDICINA           CUR-0021464
# 0                                            ECONOMIA           CUR-0018831
# 1                                          INGENIERIA           CUR-0017474
# 2                                          INGENIERIA           CUR-0018293
# 4                                          INGENIERIA           CUR-0017475
# 6                                 ARTES Y HUMANIDADES           CUR-0018846
#
#                                      Nombre.del.curso  probability_1
# 5   Programa de Liderazgo en Ingeniería - Nivel Se...       0.120000
# 7                   Ciclo de Iniciación musical EMI-2       0.705714
# 12  Curso Fuentes de financiación y formulación de...       0.830000
# 14  Curso Medicina Genómica ? aplicaciones en gené...       0.630000
# 15  Curso de Soporte Vital Avanzado ACLS (Advanced...       0.840000
# 0                 Curso de Matemáticas para Posgrados       0.210000
# 1   Programa de Liderazgo en Ingeniería - Nivel Ju...       0.010000
# 2   Programa de Liderazgo en Ingeniería - Nivel Se...       0.010000
# 4   Programa de Liderazgo en Ingeniería - Nivel Ju...       0.100000
# 6                   Ciclo de Iniciación musical EMI-1       0.635714

# %%
# df_to_append = spark.createDataFrame(df_to_append)

# %%
# df_to_append = df_to_append.withColumn('Fecha.de.inicio', F.date_format(F.to_date('`Fecha.de.inicio`', 'yyyy-MM-dd'), 'dd/MM/yyyy'))
# df_to_append = df_to_append.withColumn('Fecha.de.creación', F.date_format(F.to_date('`Fecha.de.creación`', 'yyyy-MM-dd'), 'dd/MM/yyyy'))
# df_to_append = df_to_append.withColumn('Keywords', F.col('Keywords_org'))

# %%
# df_to_append.toPandas().to_csv('/dbfs/mnt/analiticastorage_educacion-continua/99Prueba/BV_Conjunto_Entrenamiento_Original.csv', sep=';', index=False)

# %%
# df_to_append.select(
#     '`Consecutivo.del.curso`','`Nombre.del.curso`','`Fecha.de.inicio`',
#     '`Fecha.de.creación`','`Curso.nuevo`','Programa',
#     'NumCursos','NumCursosFac','Keywords','`Valor.por.hora`',
#     'Categoría','Facultad','Modalidad'
#   ).toPandas().to_csv('/dbfs/mnt/analiticastorage_educacion-continua/99Prueba/BV_Conjunto_Entrenamiento_Adaptado.csv', sep=';', index=False)
